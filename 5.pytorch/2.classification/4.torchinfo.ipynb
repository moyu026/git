# %%
import torchinfo
import torchvision.models as models

# %%
model = models.regnet_x_8gf(weights=None)
torchinfo.summary(model, input_size=(1, 3, 224, 224), depth=10)
# Out:
# ...
# Layer (type:depth-idx)                                  Output Shape              Param #
# ...
# RegNet                                                  [1, 1000]                 --
# ├─SimpleStemIN: 1-1                                     [1, 32, 112, 112]         --
# │    └─Conv2d: 2-1                                      [1, 32, 112, 112]         864
# │    └─BatchNorm2d: 2-2                                 [1, 32, 112, 112]         64
# │    └─ReLU: 2-3                                        [1, 32, 112, 112]         --
# ├─Sequential: 1-2                                       [1, 1920, 7, 7]           --
# │    └─AnyStage: 2-4                                    [1, 80, 56, 56]           --
# │    │    └─ResBottleneckBlock: 3-1                     [1, 80, 56, 56]           --
# │    │    │    └─Conv2dNormActivation: 4-1              [1, 80, 56, 56]           --
# │    │    │    │    └─Conv2d: 5-1                       [1, 80, 56, 56]           2,560
# ...
